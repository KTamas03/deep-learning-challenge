# %% [markdown]
# # <span style="color: red;">MODEL 1: remove "STATUS" & "SPECIAL_CONSIDERATIONS" columns from dataframe</span>

# %% [markdown]
# ## <span style="color: orange;"> Preprocessing - Model 1</span>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint # Import the ModelCheckpoint callback from tensorflow.keras.callbacks

#  Import and read the charity_data.csv.
import pandas as pd 
application1_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application1_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Look at STATUS value counts
status_counts = application1_df['STATUS'].value_counts()
print(status_counts)
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64

# %%
# Look at SPECIAL_CONSIDERATION value counts
special_con_counts = application1_df['SPECIAL_CONSIDERATIONS'].value_counts()
print(special_con_counts)
# Out:
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
# Drop the non-beneficial ID columns, 'EIN','NAME','STATUS' and 'SPECIAL_CONSIDERATIONS'.
application1_df=application1_df.drop(columns=['EIN','NAME','STATUS','SPECIAL_CONSIDERATIONS'])

# %%
# Determine the number of unique values in each column.
application1_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application1_type_counts = application1_df['APPLICATION_TYPE'].value_counts()
print(application1_type_counts)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# Choose cutoff value
cutoff_value = 'T10'

# Create a list of application types to be replaced
application1_types_to_replace = application1_type_counts[application1_type_counts < application1_type_counts[cutoff_value]].index.tolist()

# Replace in dataframe
for app in application1_types_to_replace:
    application1_df['APPLICATION_TYPE'] = application1_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application1_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_type_counts1 = application1_df['CLASSIFICATION'].value_counts()
print(classification_type_counts1)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# Choose a cutoff value
cutoff_value = 'C2100'

# Create a list of classifications to be replaced with "Other"
classifications_to_replace = classification_type_counts1[classification_type_counts1 < classification_type_counts1[cutoff_value]].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application1_df['CLASSIFICATION'] = application1_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application1_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

# Use pd.get_dummies to one-hot encode the categorical columns
application1_df = pd.get_dummies(application1_df)

# %%
# Split our preprocessed data into our features and target arrays
X1 = application1_df.drop(columns=['IS_SUCCESSFUL'])  # Features
y1 = application1_df['IS_SUCCESSFUL']  # Target

# Split the preprocessed data into a training and testing dataset
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, random_state=1)

# %%
# Create a StandardScaler instances
scaler1 = StandardScaler()

# Fit the StandardScaler
X_scaler1 = scaler1.fit(X_train1)

# Scale the data
X_train_scaled1 = X_scaler1.transform(X_train1)
X_test_scaled1 = X_scaler1.transform(X_test1)
print(X_test_scaled1.shape)
print(X_train_scaled1.shape)
# Out:
# (8575, 40)
# (25724, 40)

# %% [markdown]
# ## <span style="color: orange;">Compile, Train and Evaluate the Model - Model 1</span>

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model1 = tf.keras.models.Sequential()

# First hidden layer
nn_model1.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=40))

# Second hidden layer
nn_model1.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn_model1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3280
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5741 (22.43 KB)
# Trainable params: 5741 (22.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Define a callback to save the model's weights every five epochs
# Define the checkpoint path and filename
checkpoint_path_model1 = "checkpoints_model1/weights.{epoch:02d}.hdf5"

# Create a ModelCheckpoint callback that saves the model's weights every five epochs
checkpoint_callback_model1 = ModelCheckpoint(
    filepath=checkpoint_path_model1,
    save_weights_only=True,
    save_freq='epoch',
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model1 = nn_model1.fit(X_test_scaled1, y_test1, epochs=100, callbacks=[checkpoint_callback_model1])
# Out:
# Epoch 1/100
# 268/268 [==============================] - 1s 1ms/step - loss: 0.5951 - accuracy: 0.7038
# Epoch 2/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5606 - accuracy: 0.7276
# Epoch 3/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5555 - accuracy: 0.7298
# Epoch 4/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5522 - accuracy: 0.7319
# Epoch 5/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5511 - accuracy: 0.7294
# Epoch 6/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5484 - accuracy: 0.7321
# Epoch 7/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5470 - accuracy: 0.7343
# Epoch 8/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5461 - accuracy: 0.7340
# Epoch 9/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5444 - accuracy: 0.7334
# Epoch 10/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5448 - accuracy: 0.7341
# Epoch 11/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5431 - accuracy: 0.7368
# Epoch 12/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5429 - accuracy: 0.7373
# Epoch 13/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5409 - accuracy: 0.7380
# Epoch 14/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5413 - accuracy: 0.7373
# Epoch 15/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5405 - accuracy: 0.7378
# Epoch 16/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5410 - accuracy: 0.7367
# Epoch 17/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5399 - accuracy: 0.7404
# Epoch 18/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5391 - accuracy: 0.7375
# Epoch 19/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5379 - accuracy: 0.7355
# Epoch 20/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5376 - accuracy: 0.7389
# Epoch 21/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5380 - accuracy: 0.7381
# Epoch 22/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5378 - accuracy: 0.7385
# Epoch 23/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5375 - accuracy: 0.7418
# Epoch 24/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5381 - accuracy: 0.7402
# Epoch 25/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5367 - accuracy: 0.7387
# Epoch 26/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5353 - accuracy: 0.7406
# Epoch 27/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5360 - accuracy: 0.7413
# Epoch 28/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7403
# Epoch 29/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7409
# Epoch 30/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5348 - accuracy: 0.7394
# Epoch 31/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5354 - accuracy: 0.7415
# Epoch 32/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5346 - accuracy: 0.7406
# Epoch 33/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.7387
# Epoch 34/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5334 - accuracy: 0.7389
# Epoch 35/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7426
# Epoch 36/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.7413
# Epoch 37/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5334 - accuracy: 0.7420
# Epoch 38/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5326 - accuracy: 0.7445
# Epoch 39/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5343 - accuracy: 0.7417
# Epoch 40/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5330 - accuracy: 0.7410
# Epoch 41/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7410
# Epoch 42/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5324 - accuracy: 0.7415
# Epoch 43/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5320 - accuracy: 0.7427
# Epoch 44/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5324 - accuracy: 0.7420
# Epoch 45/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5324 - accuracy: 0.7429
# Epoch 46/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5319 - accuracy: 0.7415
# Epoch 47/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5329 - accuracy: 0.7441
# Epoch 48/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7431
# Epoch 49/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5318 - accuracy: 0.7418
# Epoch 50/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5318 - accuracy: 0.7423
# Epoch 51/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5316 - accuracy: 0.7424
# Epoch 52/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5309 - accuracy: 0.7438
# Epoch 53/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5313 - accuracy: 0.7416
# Epoch 54/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5307 - accuracy: 0.7434
# Epoch 55/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5311 - accuracy: 0.7433
# Epoch 56/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5311 - accuracy: 0.7425
# Epoch 57/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5306 - accuracy: 0.7436
# Epoch 58/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.7436
# Epoch 59/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5304 - accuracy: 0.7432
# Epoch 60/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5309 - accuracy: 0.7429
# Epoch 61/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5300 - accuracy: 0.7441
# Epoch 62/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5299 - accuracy: 0.7437
# Epoch 63/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5301 - accuracy: 0.7429
# Epoch 64/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5295 - accuracy: 0.7443
# Epoch 65/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.7422
# Epoch 66/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5296 - accuracy: 0.7438
# Epoch 67/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5296 - accuracy: 0.7431
# Epoch 68/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5291 - accuracy: 0.7443
# Epoch 69/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5290 - accuracy: 0.7450
# Epoch 70/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5295 - accuracy: 0.7426
# Epoch 71/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5296 - accuracy: 0.7443
# Epoch 72/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.7419
# Epoch 73/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5293 - accuracy: 0.7440
# Epoch 74/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5290 - accuracy: 0.7445
# Epoch 75/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5296 - accuracy: 0.7433
# Epoch 76/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5287 - accuracy: 0.7446
# Epoch 77/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5290 - accuracy: 0.7420
# Epoch 78/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5288 - accuracy: 0.7447
# Epoch 79/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7446
# Epoch 80/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5285 - accuracy: 0.7443
# Epoch 81/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7437
# Epoch 82/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5278 - accuracy: 0.7445
# Epoch 83/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5291 - accuracy: 0.7434
# Epoch 84/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5285 - accuracy: 0.7438
# Epoch 85/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.7436
# Epoch 86/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5285 - accuracy: 0.7440
# Epoch 87/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5283 - accuracy: 0.7439
# Epoch 88/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5276 - accuracy: 0.7441
# Epoch 89/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5279 - accuracy: 0.7433
# Epoch 90/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5278 - accuracy: 0.7438
# Epoch 91/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5277 - accuracy: 0.7453
# Epoch 92/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5276 - accuracy: 0.7430
# Epoch 93/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5277 - accuracy: 0.7445
# Epoch 94/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5277 - accuracy: 0.7434
# Epoch 95/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5279 - accuracy: 0.7446
# Epoch 96/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5271 - accuracy: 0.7431
# Epoch 97/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5274 - accuracy: 0.7422
# Epoch 98/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5267 - accuracy: 0.7438
# Epoch 99/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5272 - accuracy: 0.7453
# Epoch 100/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5278 - accuracy: 0.7418

# %%
# Evaluate the model using the test data
model1_loss, model1_accuracy = nn_model1.evaluate(X_test_scaled1,y_test1,verbose=2)
print(f"Loss: {model1_loss}, Accuracy: {model1_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5218 - accuracy: 0.7479 - 374ms/epoch - 1ms/step
# Loss: 0.5217640399932861, Accuracy: 0.7478716969490051

# %% [markdown]
# <span style="color: red;">______________________________________________________________________________________________________________________________</span>

# %% [markdown]
# # <span style="color: red;">MODEL 2 - Add More Hidden Layers and Neurons</span>

# %% [markdown]
# ## <span style="color: orange;">Preprocessing - Model 2</span>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint # Import the ModelCheckpoint callback from tensorflow.keras.callbacks

#  Import and read the charity_data.csv.
import pandas as pd 
application2_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application2_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application2_df=application2_df.drop(columns=['EIN','NAME'])

# %%
# Determine the number of unique values in each column.
application2_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application2_type_counts = application2_df['APPLICATION_TYPE'].value_counts()
print(application2_type_counts)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# Choose cutoff value
cutoff_value = 'T10'

# Create a list of application types to be replaced
application2_types_to_replace = application2_type_counts[application2_type_counts < application2_type_counts[cutoff_value]].index.tolist()

# Replace in dataframe
for app in application2_types_to_replace:
    application2_df['APPLICATION_TYPE'] = application2_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application2_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_type_counts1 = application2_df['CLASSIFICATION'].value_counts()
print(classification_type_counts1)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# Choose a cutoff value
cutoff_value = 'C2100'

# Create a list of classifications to be replaced with "Other"
classifications_to_replace = classification_type_counts1[classification_type_counts1 < classification_type_counts1[cutoff_value]].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application2_df['CLASSIFICATION'] = application2_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application2_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

# Use pd.get_dummies to one-hot encode the categorical columns
application2_df = pd.get_dummies(application2_df)

# %%
# Split our preprocessed data into our features and target arrays
X2 = application2_df.drop(columns=['IS_SUCCESSFUL'])  # Features
y2 = application2_df['IS_SUCCESSFUL']  # Target

# Split the preprocessed data into a training and testing dataset
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, random_state=1)

# %%
# Create a StandardScaler instances
scaler2 = StandardScaler()

# Fit the StandardScaler
X_scaler2 = scaler2.fit(X_train2)

# Scale the data
X_train_scaled2 = X_scaler2.transform(X_train2)
X_test_scaled2 = X_scaler2.transform(X_test2)
print(X_test_scaled2.shape)
print(X_train_scaled2.shape)
# Out:
# (8575, 43)
# (25724, 43)

# %% [markdown]
# ## <span style="color: orange;">Compile, Train and Evaluate the Model - Model 2</span>

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model2 = tf.keras.models.Sequential()

# First hidden layer
nn_model2.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=43))

# Second hidden layer
nn_model2.add(tf.keras.layers.Dense(units=80, activation="relu"))

# Third hidden layer
nn_model2.add(tf.keras.layers.Dense(units=60, activation="relu"))

# Fourth hidden layer
nn_model2.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Fifth hidden layer
nn_model2.add(tf.keras.layers.Dense(units=10, activation="relu"))

# Output layer
nn_model2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               4400
#
#  dense_4 (Dense)             (None, 80)                8080
#
#  dense_5 (Dense)             (None, 60)                4860
#
#  dense_6 (Dense)             (None, 30)                1830
#
#  dense_7 (Dense)             (None, 10)                310
#
#  dense_8 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 19491 (76.14 KB)
# Trainable params: 19491 (76.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Define a callback to save the model's weights every five epochs
# Define the checkpoint path and filename
checkpoint_path_model2 = "checkpoints_model2/weights.{epoch:02d}.hdf5"

# Create a ModelCheckpoint callback that saves the model's weights every five epochs
checkpoint_callback_model2 = ModelCheckpoint(
    filepath=checkpoint_path_model2,
    save_weights_only=True,
    save_freq='epoch',
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model2 = nn_model2.fit(X_test_scaled2, y_test2, epochs=100, callbacks=[checkpoint_callback_model2])
# Out:
# Epoch 1/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5901 - accuracy: 0.7079
# Epoch 2/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5634 - accuracy: 0.7261
# Epoch 3/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5561 - accuracy: 0.7315
# Epoch 4/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5537 - accuracy: 0.7327
# Epoch 5/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5511 - accuracy: 0.7291
# Epoch 6/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5498 - accuracy: 0.7322
# Epoch 7/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5492 - accuracy: 0.7348
# Epoch 8/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5469 - accuracy: 0.7362
# Epoch 9/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5437 - accuracy: 0.7373
# Epoch 10/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5456 - accuracy: 0.7390
# Epoch 11/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5438 - accuracy: 0.7374
# Epoch 12/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5422 - accuracy: 0.7375
# Epoch 13/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7403
# Epoch 14/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5409 - accuracy: 0.7395
# Epoch 15/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5397 - accuracy: 0.7413
# Epoch 16/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5390 - accuracy: 0.7404
# Epoch 17/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5380 - accuracy: 0.7392
# Epoch 18/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5383 - accuracy: 0.7413
# Epoch 19/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5370 - accuracy: 0.7406
# Epoch 20/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5367 - accuracy: 0.7413
# Epoch 21/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5374 - accuracy: 0.7402
# Epoch 22/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5355 - accuracy: 0.7415
# Epoch 23/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5366 - accuracy: 0.7417
# Epoch 24/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7423
# Epoch 25/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5344 - accuracy: 0.7426
# Epoch 26/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5344 - accuracy: 0.7419
# Epoch 27/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5334 - accuracy: 0.7432
# Epoch 28/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7406
# Epoch 29/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5336 - accuracy: 0.7419
# Epoch 30/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7426
# Epoch 31/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5332 - accuracy: 0.7429
# Epoch 32/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5324 - accuracy: 0.7437
# Epoch 33/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5319 - accuracy: 0.7427
# Epoch 34/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5310 - accuracy: 0.7454
# Epoch 35/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5310 - accuracy: 0.7441
# Epoch 36/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5309 - accuracy: 0.7420
# Epoch 37/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5319 - accuracy: 0.7443
# Epoch 38/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7433
# Epoch 39/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.7426
# Epoch 40/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5306 - accuracy: 0.7430
# Epoch 41/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.7432
# Epoch 42/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5290 - accuracy: 0.7446
# Epoch 43/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5292 - accuracy: 0.7441
# Epoch 44/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5290 - accuracy: 0.7443
# Epoch 45/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5273 - accuracy: 0.7451
# Epoch 46/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.7447
# Epoch 47/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5285 - accuracy: 0.7447
# Epoch 48/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5274 - accuracy: 0.7452
# Epoch 49/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5269 - accuracy: 0.7457
# Epoch 50/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5268 - accuracy: 0.7453
# Epoch 51/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5272 - accuracy: 0.7454
# Epoch 52/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5261 - accuracy: 0.7446
# Epoch 53/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7450
# Epoch 54/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.7466
# Epoch 55/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5270 - accuracy: 0.7450
# Epoch 56/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5262 - accuracy: 0.7460
# Epoch 57/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5257 - accuracy: 0.7461
# Epoch 58/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5264 - accuracy: 0.7467
# Epoch 59/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5261 - accuracy: 0.7467
# Epoch 60/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5262 - accuracy: 0.7441
# Epoch 61/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5261 - accuracy: 0.7473
# Epoch 62/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5263 - accuracy: 0.7460
# Epoch 63/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5251 - accuracy: 0.7457
# Epoch 64/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5256 - accuracy: 0.7451
# Epoch 65/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5259 - accuracy: 0.7453
# Epoch 66/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5246 - accuracy: 0.7453
# Epoch 67/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5246 - accuracy: 0.7465
# Epoch 68/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5251 - accuracy: 0.7454
# Epoch 69/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5238 - accuracy: 0.7457
# Epoch 70/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5236 - accuracy: 0.7479
# Epoch 71/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5247 - accuracy: 0.7465
# Epoch 72/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5248 - accuracy: 0.7459
# Epoch 73/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5299 - accuracy: 0.7448
# Epoch 74/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5236 - accuracy: 0.7461
# Epoch 75/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5245 - accuracy: 0.7459
# Epoch 76/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5237 - accuracy: 0.7459
# Epoch 77/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5241 - accuracy: 0.7471
# Epoch 78/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7461
# Epoch 79/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5241 - accuracy: 0.7460
# Epoch 80/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7476
# Epoch 81/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5254 - accuracy: 0.7450
# Epoch 82/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5238 - accuracy: 0.7451
# Epoch 83/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5228 - accuracy: 0.7464
# Epoch 84/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5241 - accuracy: 0.7448
# Epoch 85/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5285 - accuracy: 0.7448
# Epoch 86/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5245 - accuracy: 0.7464
# Epoch 87/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.7465
# Epoch 88/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.7464
# Epoch 89/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5223 - accuracy: 0.7471
# Epoch 90/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5225 - accuracy: 0.7471
# Epoch 91/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5221 - accuracy: 0.7475
# Epoch 92/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5216 - accuracy: 0.7461
# Epoch 93/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.7462
# Epoch 94/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5220 - accuracy: 0.7461
# Epoch 95/100
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5217 - accuracy: 0.7467
# Epoch 96/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5226 - accuracy: 0.7464
# Epoch 97/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5237 - accuracy: 0.7458
# Epoch 98/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5240 - accuracy: 0.7459
# Epoch 99/100
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5225 - accuracy: 0.7459
# Epoch 100/100
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.7471

# %%
# Evaluate the model using the test data
model2_loss, model2_accuracy = nn_model2.evaluate(X_test_scaled2,y_test2,verbose=2)
print(f"Loss: {model2_loss}, Accuracy: {model2_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5175 - accuracy: 0.7472 - 387ms/epoch - 1ms/step
# Loss: 0.5175169110298157, Accuracy: 0.7471719980239868

# %% [markdown]
# <span style="color: red;">______________________________________________________________________________________________________________________________</span>

# %% [markdown]
# # <span style="color: red;">MODEL 3 - Bin 'ASK_AMT' Column and add EPOCs </span>

# %% [markdown]
# ## <span style="color: orange;">Preprocessing - Model 3</span>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint # Import the ModelCheckpoint callback from tensorflow.keras.callbacks

#  Import and read the charity_data.csv.
import pandas as pd 
application3_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application3_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application3_df=application3_df.drop(columns=['EIN','NAME'])
application3_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application3_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application3_type_counts = application3_df['APPLICATION_TYPE'].value_counts()
print(application3_type_counts)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# Choose cutoff value
cutoff_value = 'T10'

# Create a list of application types to be replaced
application3_types_to_replace = application3_type_counts[application3_type_counts < application3_type_counts[cutoff_value]].index.tolist()

# Replace in dataframe
for app in application3_types_to_replace:
    application3_df['APPLICATION_TYPE'] = application3_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application3_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_type_counts1 = application3_df['CLASSIFICATION'].value_counts()
print(classification_type_counts1)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# Choose a cutoff value
cutoff_value = 'C2100'

# Create a list of classifications to be replaced with "Other"
classifications_to_replace = classification_type_counts1[classification_type_counts1 < classification_type_counts1[cutoff_value]].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application3_df['CLASSIFICATION'] = application3_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application3_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at ASK_AMT value counts for binning
ASK_AMT_counts1 = application3_df['ASK_AMT'].value_counts()
print(ASK_AMT_counts1)
# Out:
# 5000        25398
# 10478           3
# 15583           3
# 63981           3
# 6725            3
#             ...
# 5371754         1
# 30060           1
# 43091152        1
# 18683           1
# 36500179        1
# Name: ASK_AMT, Length: 8747, dtype: int64

# %%
# Create bins for the ASK_AMT column and put in new column ASK_AMT_Binned
# Define bin edges
bin_edges = [0, 1000000, 10000000, float("inf")]

# Create labels for the bins
bin_labels = ["1", "2", "3"]

# Use pd.cut() to create the 'ASK_AMT_Binned' column
application3_df['ASK_AMT_Binned'] = pd.cut(application3_df['ASK_AMT'], bins=bin_edges, labels=bin_labels, include_lowest=True)

# Display the DataFrame with the 'ASK_AMT_Binned' column
print(application3_df[['ASK_AMT', 'ASK_AMT_Binned']])
# Out:
#         ASK_AMT ASK_AMT_Binned
# 0          5000              1
# 1        108590              1
# 2          5000              1
# 3          6692              1
# 4        142590              1
# ...         ...            ...
# 34294      5000              1
# 34295      5000              1
# 34296      5000              1
# 34297      5000              1
# 34298  36500179              3
#
# [34299 rows x 2 columns]

# %%
# Drop ASK_AMT column as it is replaced by the ASK_AMT_Binned column
application3_df = application3_df.drop('ASK_AMT', axis=1)
application3_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  \
# 0       Association       1              0                      N
# 1      Co-operative       1         1-9999                      N
# 2       Association       1              0                      N
# 3             Trust       1    10000-24999                      N
# 4             Trust       1  100000-499999                      N
# ...             ...     ...            ...                    ...
# 34294   Association       1              0                      N
# 34295   Association       1              0                      N
# 34296   Association       1              0                      N
# 34297   Association       1              0                      N
# 34298  Co-operative       1          1M-5M                      N
#
#        IS_SUCCESSFUL ASK_AMT_Binned
# 0                  1              1
# 1                  1              1
# 2                  0              1
# 3                  1              1
# 4                  1              1
# ...              ...            ...
# 34294              0              1
# 34295              0              1
# 34296              0              1
# 34297              1              1
# 34298              0              3
#
# [34299 rows x 10 columns]

# %%
# Check ASK_AMT_Binned column value counts for binning worked
application3_type_counts = application3_df['ASK_AMT_Binned'].value_counts()
print(application3_type_counts)
# Out:
# 1    32722
# 2     1165
# 3      412
# Name: ASK_AMT_Binned, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

# Use pd.get_dummies to one-hot encode the categorical columns
application3_df = pd.get_dummies(application3_df)

# %%
# Split our preprocessed data into our features and target arrays
X3 = application3_df.drop(columns=['IS_SUCCESSFUL'])  # Features
y3 = application3_df['IS_SUCCESSFUL']  # Target

# Split the preprocessed data into a training and testing dataset
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, random_state=1)

# %%
# Create a StandardScaler instances
scaler3 = StandardScaler()

# Fit the StandardScaler
X_scaler3 = scaler3.fit(X_train3)

# Scale the data
X_train_scaled3 = X_scaler3.transform(X_train3)
X_test_scaled3 = X_scaler3.transform(X_test3)
print(X_test_scaled3.shape)
print(X_train_scaled3.shape)
# Out:
# (8575, 45)
# (25724, 45)

# %% [markdown]
# ## <span style="color: orange;">Compile, Train and Evaluate the Model - Model 3</span>

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model3 = tf.keras.models.Sequential()

# First hidden layer
nn_model3.add(tf.keras.layers.Dense(units=100, activation="relu", input_dim=45))

# Second hidden layer
nn_model3.add(tf.keras.layers.Dense(units=80, activation="relu"))

# Output layer
nn_model3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 100)               4600
#
#  dense_10 (Dense)            (None, 80)                8080
#
#  dense_11 (Dense)            (None, 1)                 81
#
# =================================================================
# Total params: 12761 (49.85 KB)
# Trainable params: 12761 (49.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Define a callback to save the model's weights every five epochs
# Define the checkpoint path and filename
checkpoint_path_model3 = "checkpoints_model3/weights.{epoch:02d}.hdf5"

# Create a ModelCheckpoint callback that saves the model's weights every five epochs
checkpoint_callback_model3 = ModelCheckpoint(
    filepath=checkpoint_path_model3,
    save_weights_only=True,
    save_freq='epoch',
    period=5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model3 = nn_model3.fit(X_test_scaled3, y_test3, epochs=150, callbacks=[checkpoint_callback_model3])
# Out:
# Epoch 1/150
# 268/268 [==============================] - 1s 1ms/step - loss: 0.5837 - accuracy: 0.7122
# Epoch 2/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5639 - accuracy: 0.7275
# Epoch 3/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5577 - accuracy: 0.7307
# Epoch 4/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5534 - accuracy: 0.7305
# Epoch 5/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5530 - accuracy: 0.7306
# Epoch 6/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5501 - accuracy: 0.7335
# Epoch 7/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5472 - accuracy: 0.7352
# Epoch 8/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5479 - accuracy: 0.7343
# Epoch 9/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5459 - accuracy: 0.7312
# Epoch 10/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5443 - accuracy: 0.7324
# Epoch 11/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5445 - accuracy: 0.7347
# Epoch 12/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5426 - accuracy: 0.7349
# Epoch 13/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5416 - accuracy: 0.7387
# Epoch 14/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5408 - accuracy: 0.7384
# Epoch 15/150
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5402 - accuracy: 0.7362
# Epoch 16/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5403 - accuracy: 0.7349
# Epoch 17/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5391 - accuracy: 0.7402
# Epoch 18/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5377 - accuracy: 0.7390
# Epoch 19/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5371 - accuracy: 0.7380
# Epoch 20/150
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5376 - accuracy: 0.7391
# Epoch 21/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5370 - accuracy: 0.7385
# Epoch 22/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5354 - accuracy: 0.7411
# Epoch 23/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7385
# Epoch 24/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5350 - accuracy: 0.7410
# Epoch 25/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5347 - accuracy: 0.7422
# Epoch 26/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5347 - accuracy: 0.7420
# Epoch 27/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5342 - accuracy: 0.7419
# Epoch 28/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5343 - accuracy: 0.7419
# Epoch 29/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5327 - accuracy: 0.7406
# Epoch 30/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5328 - accuracy: 0.7403
# Epoch 31/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5325 - accuracy: 0.7413
# Epoch 32/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5336 - accuracy: 0.7415
# Epoch 33/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5315 - accuracy: 0.7423
# Epoch 34/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5311 - accuracy: 0.7438
# Epoch 35/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5307 - accuracy: 0.7419
# Epoch 36/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5312 - accuracy: 0.7431
# Epoch 37/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5309 - accuracy: 0.7432
# Epoch 38/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5313 - accuracy: 0.7419
# Epoch 39/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.7422
# Epoch 40/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.7437
# Epoch 41/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5304 - accuracy: 0.7439
# Epoch 42/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5301 - accuracy: 0.7440
# Epoch 43/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5298 - accuracy: 0.7437
# Epoch 44/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.7415
# Epoch 45/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5288 - accuracy: 0.7437
# Epoch 46/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5289 - accuracy: 0.7438
# Epoch 47/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5298 - accuracy: 0.7410
# Epoch 48/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5295 - accuracy: 0.7439
# Epoch 49/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5280 - accuracy: 0.7451
# Epoch 50/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5280 - accuracy: 0.7423
# Epoch 51/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5280 - accuracy: 0.7458
# Epoch 52/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5275 - accuracy: 0.7464
# Epoch 53/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5270 - accuracy: 0.7426
# Epoch 54/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5273 - accuracy: 0.7445
# Epoch 55/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5271 - accuracy: 0.7431
# Epoch 56/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5267 - accuracy: 0.7437
# Epoch 57/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5267 - accuracy: 0.7462
# Epoch 58/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5265 - accuracy: 0.7453
# Epoch 59/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5287 - accuracy: 0.7419
# Epoch 60/150
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5267 - accuracy: 0.7447
# Epoch 61/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5262 - accuracy: 0.7440
# Epoch 62/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5262 - accuracy: 0.7461
# Epoch 63/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5258 - accuracy: 0.7447
# Epoch 64/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5257 - accuracy: 0.7430
# Epoch 65/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5250 - accuracy: 0.7436
# Epoch 66/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5243 - accuracy: 0.7451
# Epoch 67/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5256 - accuracy: 0.7451
# Epoch 68/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5250 - accuracy: 0.7448
# Epoch 69/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5250 - accuracy: 0.7424
# Epoch 70/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.7452
# Epoch 71/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5250 - accuracy: 0.7455
# Epoch 72/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.7450
# Epoch 73/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5245 - accuracy: 0.7441
# Epoch 74/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5243 - accuracy: 0.7433
# Epoch 75/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5238 - accuracy: 0.7438
# Epoch 76/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5242 - accuracy: 0.7461
# Epoch 77/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5241 - accuracy: 0.7447
# Epoch 78/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5239 - accuracy: 0.7440
# Epoch 79/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.7440
# Epoch 80/150
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5237 - accuracy: 0.7451
# Epoch 81/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.7462
# Epoch 82/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5246 - accuracy: 0.7461
# Epoch 83/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5232 - accuracy: 0.7459
# Epoch 84/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5234 - accuracy: 0.7466
# Epoch 85/150
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5235 - accuracy: 0.7455
# Epoch 86/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.7471
# Epoch 87/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5236 - accuracy: 0.7461
# Epoch 88/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7451
# Epoch 89/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.7446
# Epoch 90/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7458
# Epoch 91/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7452
# Epoch 92/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.7446
# Epoch 93/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5236 - accuracy: 0.7451
# Epoch 94/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5246 - accuracy: 0.7450
# Epoch 95/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5228 - accuracy: 0.7465
# Epoch 96/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.7457
# Epoch 97/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5232 - accuracy: 0.7451
# Epoch 98/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5226 - accuracy: 0.7458
# Epoch 99/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7464
# Epoch 100/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5231 - accuracy: 0.7460
# Epoch 101/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5223 - accuracy: 0.7474
# Epoch 102/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.7464
# Epoch 103/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5208 - accuracy: 0.7446
# Epoch 104/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.7436
# Epoch 105/150
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.7454
# Epoch 106/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.7466
# Epoch 107/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5213 - accuracy: 0.7450
# Epoch 108/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5221 - accuracy: 0.7467
# Epoch 109/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.7445
# Epoch 110/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.7465
# Epoch 111/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5212 - accuracy: 0.7466
# Epoch 112/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5213 - accuracy: 0.7465
# Epoch 113/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5210 - accuracy: 0.7465
# Epoch 114/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.7468
# Epoch 115/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.7471
# Epoch 116/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5212 - accuracy: 0.7458
# Epoch 117/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.7473
# Epoch 118/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5214 - accuracy: 0.7458
# Epoch 119/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.7472
# Epoch 120/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5203 - accuracy: 0.7457
# Epoch 121/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5209 - accuracy: 0.7461
# Epoch 122/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.7471
# Epoch 123/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5229 - accuracy: 0.7466
# Epoch 124/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5198 - accuracy: 0.7459
# Epoch 125/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5207 - accuracy: 0.7466
# Epoch 126/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5208 - accuracy: 0.7473
# Epoch 127/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5210 - accuracy: 0.7462
# Epoch 128/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.7457
# Epoch 129/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5206 - accuracy: 0.7466
# Epoch 130/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5202 - accuracy: 0.7464
# Epoch 131/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5208 - accuracy: 0.7469
# Epoch 132/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5208 - accuracy: 0.7455
# Epoch 133/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5202 - accuracy: 0.7464
# Epoch 134/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5203 - accuracy: 0.7468
# Epoch 135/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5203 - accuracy: 0.7473
# Epoch 136/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5209 - accuracy: 0.7472
# Epoch 137/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5200 - accuracy: 0.7466
# Epoch 138/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5205 - accuracy: 0.7457
# Epoch 139/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5200 - accuracy: 0.7467
# Epoch 140/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5208 - accuracy: 0.7469
# Epoch 141/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5201 - accuracy: 0.7472
# Epoch 142/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5203 - accuracy: 0.7474
# Epoch 143/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.7469
# Epoch 144/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5241 - accuracy: 0.7460
# Epoch 145/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.7467
# Epoch 146/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5191 - accuracy: 0.7469
# Epoch 147/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5201 - accuracy: 0.7480
# Epoch 148/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5196 - accuracy: 0.7478
# Epoch 149/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5196 - accuracy: 0.7475
# Epoch 150/150
# 268/268 [==============================] - 0s 1ms/step - loss: 0.5202 - accuracy: 0.7461

# %%
# Evaluate the model using the test data
model3_loss, model3_accuracy = nn_model3.evaluate(X_test_scaled3,y_test3,verbose=2)
print(f"Model 3 Loss: {model3_loss}, Model 3 Accuracy: {model3_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5150 - accuracy: 0.7493 - 350ms/epoch - 1ms/step
# Model 3 Loss: 0.515017032623291, Model 3 Accuracy: 0.7492711544036865

# %% [markdown]
# <span style="color: red;">______________________________________________________________________________________________________________________________</span>

# %% [markdown]
# # <span style="color: red;">Summary Results</span>

# %%
print(f"Model 1 Loss: {model1_loss}, Model 1 Accuracy: {model1_accuracy}")
print(f"Model 2 Loss: {model2_loss}, Model 2 Accuracy: {model2_accuracy}")
print(f"Model 3 Loss: {model3_loss}, Model 3 Accuracy: {model3_accuracy}")
# Out:
# Model 1 Loss: 0.5217640399932861, Model 1 Accuracy: 0.7478716969490051
# Model 2 Loss: 0.5175169110298157, Model 2 Accuracy: 0.7471719980239868
# Model 3 Loss: 0.515017032623291, Model 3 Accuracy: 0.7492711544036865

# %% [markdown]
# ### <span style="color: blue;">Model 3 is the best model</span>

# %%
# Export best model to HDF5 file
nn_model3.save("AlphabetSoupCharity_Optimisation.h5")
# Out:
# C:\Users\Tamas\anaconda3\envs\dev\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
